# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression
# %matplotlib notebook

# %%
x,y=make_regression(n_samples=1000,n_features=2,random_state=1,noise=10)# random state means that each time this will 
# produce same data
print(x.shape)
print(y.shape)
# Out:
# (1000, 2)
# (1000,)

# %%
plt.subplot(1,2,1)
plt.scatter(x[:,0],y)

plt.subplot(1,2,2)
plt.scatter(x[:,1],y)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# 3D Visualization
from mpl_toolkits import mplot3d
fig=plt.figure(figsize=(10,6))
axes=plt.axes(projection="3d")
axes.scatter3D(x[:,0],x[:,1],y,cmap="rainbow",color="orange")
plt.title(" 3D scatter plot")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1562.24">

# %% [markdown]
# ### Implementing Linear Regression using sklearn

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
# train the model
model.fit(x,y)
# Out:
# LinearRegression()

# %%
model.coef_# are T1,T2 and so on
# Out:
# array([16.62437639, 87.99042847])

# %%
model.intercept_# T0
# Out:
# -0.21766413760018377

# %%
model.predict([x[0],x[1]])# return y^[0] and y^[1]
# Out:
# array([-186.58153868,  -90.66624357])

# %%
y[0],y[1]
# Out:
# (-198.36714169030483, -71.87770558832477)

# %%
model.score(x,y)
# Out:
# 0.988401838483157
